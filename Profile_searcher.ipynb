# %%
import requests , time
import os
from typing import List, Dict

GOOGLE_API_KEY = "AIzaSyBXi7QrGLclLy_tlYd-K6b2NP2gYfU27uc"
SEARCH_ENGINE_ID = "d2427cde8f66c447d"

def find_linkedin_profiles(full_name: str, college: str, batch_year: str, num_results: int = 1) -> List[Dict[str, str]]:
    query = f"{full_name} {college} {batch_year} site:linkedin.com/in OR site:linkedin.com/pub"
    url = "https://www.googleapis.com/customsearch/v1"
    
    params = {
        'key': GOOGLE_API_KEY,
        'cx': SEARCH_ENGINE_ID,
        'q': query,
        'num': num_results
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        search_results = response.json()
        
        profiles = []
        for item in search_results.get('items', []):
            profile = {
                'name': item.get('title', '').split('-')[0].strip(),
                'title': item.get('title', '').split('-')[1].strip() if '-' in item.get('title', '') else '',
                'url': item.get('link', ''),
                'snippet': item.get('snippet', '')
            }
            profiles.append(profile)
        
        return profiles
    
    except requests.RequestException as e:
        print(f"An error occurred: {e}")
        return []

def main():
    college = "Birla Institute of Technology and Science"
    profiles = find_linkedin_profiles(full_name, college,year)
    if profiles:
        print(f"\nFound {len(profiles)} LinkedIn profiles:")
        for profile in profiles:
            print(f"Name: {profile['name']}")
            print(f"Title: {profile['title']}")
            print(f"URL: {profile['url']}")
            print(f"Snippet: {profile['snippet']}")
            print()
    else:
        print("No LinkedIn profiles found.")
        
        
        

if __name__ == "__main__":
    names = {"K Srikanth"}
    batch_year = {"1988"}
    for full_name in names :
        for year in batch_year :
            main()
        time.sleep(1)

# %%
# Out:
# Found 1 LinkedIn profiles:
# Name: Srikanth Davuluri
# Title: Senior Delivery Partner
# URL: https://in.linkedin.com/in/srikanth-davuluri-bb81b4b
# Snippet: Birla Institute of Technology, Mesra Graphic · Birla Institute of Technology ... Johns High School, Karimnagar. SSC Mathematics, Science. 1991 - 1992.

# %%
# Deployment methods for non profits - 
# 
# We have to store cookies and user data somewhere apart from heroku to avoid memory REM
# try redis(used for caching)

# %%
# Digital ocean  
# Heroku dyno optimisation

# %%
# Explore AWS free tier 
# Explore Azure for non profits 
# Explore Digital Ocean for non profits

# %%
# has to be long lasting ,

# %%
# Explore AWS free tier - Exploring EC2 , Lambda , 
# Explore Azure for non profits 
# Explore Digital Ocean for non profits - Requires Credit Card information

# %%
# Add the whatsapp groups 
# the details about the google sheets

# %%
# screen share karde
